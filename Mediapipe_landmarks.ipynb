# %%
import os
import cv2
import json
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/v1.0/InfinityAI_InfiniteRep_fly_v1.0.zip
# Out:
# Archive:  /content/drive/MyDrive/v1.0/InfinityAI_InfiniteRep_fly_v1.0.zip
#    creating: data/
#  extracting: data/000030_img_labels.zip
#  extracting: data/000025_img_labels.zip
#   inflating: data/000000.json
#   inflating: data/000038.mp4
#   inflating: data/000010.mp4
#   inflating: data/000057.json
#   inflating: data/000004.mp4
#  extracting: data/000054_img_labels.zip
#  extracting: data/000041_img_labels.zip
#   inflating: data/000041.json
#   inflating: data/000016.json
#   inflating: data/000082.json
#  extracting: data/000049_img_labels.zip
#   inflating: data/000005.mp4
#   inflating: data/000011.mp4
#   inflating: data/000039.mp4
#  extracting: data/000038_img_labels.zip
#   inflating: data/000094.json
#  extracting: data/000022_img_labels.zip
#  extracting: data/000037_img_labels.zip
#   inflating: data/000007.mp4
#   inflating: data/000013.mp4
#  extracting: data/000046_img_labels.zip
#  extracting: data/000053_img_labels.zip
#   inflating: data/000061.json
#   inflating: data/000036.json
#   inflating: data/000012.mp4
#   inflating: data/000006.mp4
#   inflating: data/000020.json
#   inflating: data/000077.json
#   inflating: data/000098.json
#   inflating: data/000076.json
#   inflating: data/000099.json
#   inflating: data/000002.mp4
#   inflating: data/000021.json
#   inflating: data/000016.mp4
#   inflating: data/000037.json
#   inflating: data/000060.json
#  extracting: data/000036_img_labels.zip
#  extracting: data/000023_img_labels.zip
#   inflating: data/000017.mp4
#  extracting: data/000052_img_labels.zip
#  extracting: data/000047_img_labels.zip
#   inflating: data/000003.mp4
#   inflating: data/000095.json
#  extracting: data/000048_img_labels.zip
#   inflating: data/000015.mp4
#   inflating: data/000001.mp4
#   inflating: data/000029.mp4
#  extracting: data/000039_img_labels.zip
#   inflating: data/000083.json
#   inflating: data/000017.json
#   inflating: data/000040.json
#  extracting: data/000024_img_labels.zip
#  extracting: data/000031_img_labels.zip
#   inflating: data/000028.mp4
#   inflating: data/000000.mp4
#   inflating: data/000056.json
#   inflating: data/000014.mp4
#   inflating: data/000001.json
#  extracting: data/000040_img_labels.zip
#  extracting: data/000055_img_labels.zip
#   inflating: data/000098.mp4
#   inflating: data/000073.mp4
#   inflating: data/000067.mp4
#   inflating: data/000067.json
#  extracting: data/000042_img_labels.zip
#  extracting: data/000057_img_labels.zip
#   inflating: data/000088.json
#   inflating: data/000030.json
#   inflating: data/000066.mp4
#   inflating: data/000026.json
#  extracting: data/000026_img_labels.zip
#   inflating: data/000072.mp4
#  extracting: data/000033_img_labels.zip
#   inflating: data/000099.mp4
#   inflating: data/000071.json
#  extracting: data/000029_img_labels.zip
#   inflating: data/000006.json
#   inflating: data/000058.mp4
#   inflating: data/000064.mp4
#   inflating: data/000070.mp4
#   inflating: data/000051.json
#  extracting: data/000058_img_labels.zip
#   inflating: data/000047.json
#   inflating: data/000010.json
#   inflating: data/000084.json
#  extracting: data/000050_img_labels.zip
#  extracting: data/000045_img_labels.zip
#   inflating: data/000071.mp4
#   inflating: data/000065.mp4
#   inflating: data/000059.mp4
#  extracting: data/000034_img_labels.zip
#  extracting: data/000021_img_labels.zip
#   inflating: data/000092.json
#  extracting: data/000044_img_labels.zip
#  extracting: data/000051_img_labels.zip
#   inflating: data/000093.json
#   inflating: data/000061.mp4
#   inflating: data/000075.mp4
#   inflating: data/000049.mp4
#  extracting: data/000020_img_labels.zip
#  extracting: data/000035_img_labels.zip
#   inflating: data/000085.json
#   inflating: data/000011.json
#   inflating: data/000046.json
#  extracting: data/000028_img_labels.zip
#   inflating: data/000048.mp4
#   inflating: data/000074.mp4
#   inflating: data/000060.mp4
#   inflating: data/000050.json
#   inflating: data/000007.json
#  extracting: data/000059_img_labels.zip
#   inflating: data/000070.json
#   inflating: data/000089.mp4
#   inflating: data/000027.json
#   inflating: data/000076.mp4
#   inflating: data/000062.mp4
#  extracting: data/000056_img_labels.zip
#  extracting: data/000043_img_labels.zip
#   inflating: data/000031.json
#   inflating: data/000066.json
#  extracting: data/000032_img_labels.zip
#  extracting: data/000027_img_labels.zip
#   inflating: data/000089.json
#   inflating: data/000063.mp4
#   inflating: data/000077.mp4
#   inflating: data/000088.mp4
#  extracting: data/000062_img_labels.zip
#  extracting: data/000077_img_labels.zip
#   inflating: data/000073.json
#   inflating: data/000091.mp4
#   inflating: data/000085.mp4
#   inflating: data/000052.mp4
#   inflating: data/000024.json
#   inflating: data/000046.mp4
#  extracting: data/000006_img_labels.zip
#  extracting: data/000013_img_labels.zip
#   inflating: data/000032.json
#  extracting: data/000088_img_labels.zip
#   inflating: data/000065.json
#  extracting: data/000095_img_labels.zip
#  extracting: data/000080_img_labels.zip
#   inflating: data/000049.json
#   inflating: data/000047.mp4
#   inflating: data/000053.mp4
#   inflating: data/000084.mp4
#   inflating: data/000090.mp4
#   inflating: data/000008.json
#   inflating: data/000090.json
#   inflating: data/000086.mp4
#   inflating: data/000028.json
#   inflating: data/000092.mp4
#  extracting: data/000070_img_labels.zip
#  extracting: data/000065_img_labels.zip
#   inflating: data/000079.mp4
#   inflating: data/000045.mp4
#   inflating: data/000051.mp4
#   inflating: data/000086.json
#  extracting: data/000014_img_labels.zip
#  extracting: data/000001_img_labels.zip
#   inflating: data/000069.json
#   inflating: data/000012.json
#  extracting: data/000009_img_labels.zip
#   inflating: data/000045.json
#  extracting: data/000087_img_labels.zip
#  extracting: data/000092_img_labels.zip
#   inflating: data/000050.mp4
#   inflating: data/000053.json
#   inflating: data/000044.mp4
#   inflating: data/000078.mp4
#   inflating: data/000093.mp4
#   inflating: data/000087.mp4
#  extracting: data/000078_img_labels.zip
#   inflating: data/000004.json
#   inflating: data/000005.json
#  extracting: data/000093_img_labels.zip
#  extracting: data/000086_img_labels.zip
#   inflating: data/000083.mp4
#   inflating: data/000097.mp4
#  extracting: data/000008_img_labels.zip
#   inflating: data/000040.mp4
#   inflating: data/000052.json
#   inflating: data/000054.mp4
#   inflating: data/000068.mp4
#   inflating: data/000044.json
#  extracting: data/000079_img_labels.zip
#   inflating: data/000013.json
#  extracting: data/000064_img_labels.zip
#  extracting: data/000071_img_labels.zip
#   inflating: data/000087.json
#   inflating: data/000068.json
#   inflating: data/000069.mp4
#   inflating: data/000055.mp4
#   inflating: data/000041.mp4
#  extracting: data/000000_img_labels.zip
#  extracting: data/000015_img_labels.zip
#   inflating: data/000029.json
#   inflating: data/000096.mp4
#   inflating: data/000082.mp4
#   inflating: data/000091.json
#   inflating: data/_README.txt
#   inflating: data/000009.json
#   inflating: data/000094.mp4
#  extracting: data/000081_img_labels.zip
#  extracting: data/000094_img_labels.zip
#   inflating: data/000080.mp4
#   inflating: data/000057.mp4
#   inflating: data/000043.mp4
#   inflating: data/000048.json
#   inflating: data/000064.json
#  extracting: data/000076_img_labels.zip
#  extracting: data/000063_img_labels.zip
#   inflating: data/000033.json
#   inflating: data/000042.mp4
#   inflating: data/000056.mp4
#   inflating: data/000025.json
#   inflating: data/000081.mp4
#  extracting: data/000089_img_labels.zip
#   inflating: data/000095.mp4
#   inflating: data/000072.json
#  extracting: data/000012_img_labels.zip
#  extracting: data/000007_img_labels.zip
#   inflating: data/000096.json
#   inflating: data/000079.json
#  extracting: data/000069_img_labels.zip
#   inflating: data/000019.mp4
#   inflating: data/000031.mp4
#   inflating: data/000025.mp4
#   inflating: data/000038.json
#  extracting: data/000083_img_labels.zip
#  extracting: data/000096_img_labels.zip
#   inflating: data/000080.json
#  extracting: data/000018_img_labels.zip
#   inflating: data/000014.json
#  extracting: data/000010_img_labels.zip
#  extracting: data/000005_img_labels.zip
#   inflating: data/000043.json
#   inflating: data/000024.mp4
#   inflating: data/000030.mp4
#   inflating: data/000055.json
#   inflating: data/000018.mp4
#  extracting: data/000074_img_labels.zip
#  extracting: data/000061_img_labels.zip
#   inflating: data/000002.json
#   inflating: data/000075.json
#   inflating: data/000022.json
#   inflating: data/000026.mp4
#   inflating: data/000032.mp4
#   inflating: data/000034.json
#  extracting: data/000091_img_labels.zip
#  extracting: data/000084_img_labels.zip
#   inflating: data/000063.json
#   inflating: data/000018.json
#  extracting: data/000099_img_labels.zip
#  extracting: data/000002_img_labels.zip
#  extracting: data/000017_img_labels.zip
#   inflating: data/000033.mp4
#   inflating: data/000027.mp4
#   inflating: data/000059.json
#  extracting: data/000066_img_labels.zip
#  extracting: data/000073_img_labels.zip
#  extracting: data/000016_img_labels.zip
#  extracting: data/000003_img_labels.zip
#   inflating: data/000058.json
#  extracting: data/000098_img_labels.zip
#   inflating: data/000023.mp4
#   inflating: data/000037.mp4
#  extracting: data/000072_img_labels.zip
#  extracting: data/000067_img_labels.zip
#   inflating: data/000019.json
#   inflating: data/000062.json
#   inflating: data/000035.json
#   inflating: data/000036.mp4
#   inflating: data/000023.json
#   inflating: data/000022.mp4
#  extracting: data/000085_img_labels.zip
#  extracting: data/000090_img_labels.zip
#   inflating: data/000074.json
#   inflating: data/000003.json
#  extracting: data/000004_img_labels.zip
#  extracting: data/000011_img_labels.zip
#   inflating: data/000034.mp4
#   inflating: data/000020.mp4
#   inflating: data/000054.json
#   inflating: data/000008.mp4
#   inflating: data/000042.json
#  extracting: data/000060_img_labels.zip
#  extracting: data/000075_img_labels.zip
#   inflating: data/000015.json
#   inflating: data/000081.json
#  extracting: data/000068_img_labels.zip
#   inflating: data/000039.json
#   inflating: data/000009.mp4
#   inflating: data/000021.mp4
#   inflating: data/000035.mp4
#  extracting: data/000019_img_labels.zip
#  extracting: data/000097_img_labels.zip
#  extracting: data/000082_img_labels.zip
#   inflating: data/000097.json
#   inflating: data/000078.json
#    creating: give_me_more_data/
#   inflating: give_me_more_data/synthetic_data_on_demand.txt

# %%
# !pip install mediapipe opencv-python
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 48.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.22.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.1 sounddevice-0.4.6

# %%
import cv2
from google.colab.patches import cv2_imshow
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
cap = cv2.VideoCapture("/content/data/000000.mp4")
while cap.isOpened():
    ret, frame = cap.read()
    cv2_imshow(frame)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
